# %%
# Install necessary requirements
# !pip install matplotlib
# !pip install pandas
# !pip install pillow
# !pip install scipy

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import random
import numpy as np
# Out:
# 2023-09-11 06:45:11.940357: I tensorflow/compiler/xla/stream_executor/tpu/tpu_initializer_helper.cc:269] Libtpu path is: libtpu.so
# D0911 06:45:12.143199005   13004 config.cc:112]                        gRPC EXPERIMENT tcp_frame_size_tuning               OFF (default:OFF)
# D0911 06:45:12.143221190   13004 config.cc:112]                        gRPC EXPERIMENT tcp_rcv_lowat                       OFF (default:OFF)
# D0911 06:45:12.143226197   13004 config.cc:112]                        gRPC EXPERIMENT peer_state_based_framing            OFF (default:OFF)
# D0911 06:45:12.143230652   13004 config.cc:112]                        gRPC EXPERIMENT flow_control_fixes                  ON  (default:ON)
# D0911 06:45:12.143234967   13004 config.cc:112]                        gRPC EXPERIMENT memory_pressure_controller          OFF (default:OFF)
# D0911 06:45:12.143239188   13004 config.cc:112]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size OFF (default:OFF)
# D0911 06:45:12.143243320   13004 config.cc:112]                        gRPC EXPERIMENT event_engine_client                 OFF (default:OFF)
# D0911 06:45:12.143247454   13004 config.cc:112]                        gRPC EXPERIMENT monitoring_experiment               ON  (default:ON)
# D0911 06:45:12.143251574   13004 config.cc:112]                        gRPC EXPERIMENT promise_based_client_call           OFF (default:OFF)
# D0911 06:45:12.143255693   13004 config.cc:112]                        gRPC EXPERIMENT free_large_allocator                OFF (default:OFF)
# D0911 06:45:12.143259773   13004 config.cc:112]                        gRPC EXPERIMENT promise_based_server_call           OFF (default:OFF)
# D0911 06:45:12.143263948   13004 config.cc:112]                        gRPC EXPERIMENT transport_supplies_client_latency   OFF (default:OFF)
# D0911 06:45:12.143268077   13004 config.cc:112]                        gRPC EXPERIMENT event_engine_listener               OFF (default:OFF)
# D0911 06:45:12.143272274   13004 config.cc:112]                        gRPC EXPERIMENT schedule_cancellation_over_write    OFF (default:OFF)
# D0911 06:45:12.143276356   13004 config.cc:112]                        gRPC EXPERIMENT trace_record_callops                OFF (default:OFF)
# D0911 06:45:12.143280488   13004 config.cc:112]                        gRPC EXPERIMENT event_engine_dns                    OFF (default:OFF)
# I0911 06:45:12.143522623   13004 ev_epoll1_linux.cc:122]               grpc epoll fd: 63
# D0911 06:45:12.143535442   13004 ev_posix.cc:113]                      Using polling engine: epoll1
# D0911 06:45:12.143824516   13004 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D0911 06:45:12.143832113   13004 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D0911 06:45:12.143841715   13004 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D0911 06:45:12.143846808   13004 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D0911 06:45:12.143851880   13004 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D0911 06:45:12.143856977   13004 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin"
# D0911 06:45:12.143867162   13004 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D0911 06:45:12.143891062   13004 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D0911 06:45:12.143910297   13004 dns_resolver_plugin.cc:44]            Using ares dns resolver
# D0911 06:45:12.143930181   13004 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D0911 06:45:12.143950286   13004 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D0911 06:45:12.143955705   13004 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D0911 06:45:12.143961130   13004 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D0911 06:45:12.143966506   13004 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_resolver_experimental"
# D0911 06:45:12.143973865   13004 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D0911 06:45:12.143978888   13004 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D0911 06:45:12.143988448   13004 certificate_provider_registry.cc:35]  registering certificate provider factory for "file_watcher"
# I0911 06:45:12.145570216   13004 ev_epoll1_linux.cc:362]               grpc epoll fd: 65
# I0911 06:45:12.169872284   13114 socket_utils_common_posix.cc:337]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# 2023-09-11 06:45:12.222438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def show_img(path):
    image_path = path
    img = mpimg.imread(image_path)
    
    # Display the image
    plt.imshow(img)
    plt.axis('off')  # Turn off axis labels and ticks
    plt.show()

def read_file(path):
    file_path =  path

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    return df

# %%
show_img('dataset/train/left/zzv.jpg')
train = read_file('dataset/train.csv')

# %%
left_datagen = ImageDataGenerator(
    rescale=1./255,         # Rescale pixel values to [0, 1]
    rotation_range=20,      # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # Randomly shift image width by up to 20%
    height_shift_range=0.2, # Randomly shift image height by up to 20%
    shear_range=0.2,        # Shear transformations
    zoom_range=0.2,         # Randomly zoom in on images by up to 20%
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'     # Fill mode for newly created pixels
)

right_datagen = ImageDataGenerator(
    rescale=1./255,         # Rescale pixel values to [0, 1]
    rotation_range=20,      # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,  # Randomly shift image width by up to 20%
    height_shift_range=0.2, # Randomly shift image height by up to 20%
    shear_range=0.2,        # Shear transformations
    zoom_range=0.2,         # Randomly zoom in on images by up to 20%
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'     # Fill mode for newly created pixels
)

# Set the batch size and image size
batch_size = 32
image_size = (150, 150)

# Create generators for "left" and "right" images
left_generator = left_datagen.flow_from_directory(
    'dataset/train',  # Path to the "left" image folder
    target_size=image_size,
    batch_size=batch_size,
    class_mode= None       
)

right_generator = right_datagen.flow_from_directory(
    'dataset/train', # Path to the "right" image folder
    target_size=image_size,
    batch_size=batch_size,
    class_mode= None    
)

for left_img, right_img in zip(left_generator, right_generator):
# Out:
# Found 4001 images belonging to 2 classes.
# Found 4001 images belonging to 2 classes.

# %%
# Get a batch of images from the generators
left_batch= next(left_generator)  # We don't need labels for display
right_batch = next(right_generator)  # We don't need labels for display

# Define the number of images to display
num_images_to_display = 3

# Display a few images from the batch
plt.figure(figsize=(12, 6))

for i in range(num_images_to_display):
    plt.subplot(2, num_images_to_display, i + 1)
    plt.imshow(left_batch[i])
    plt.title("Left Image")
    plt.axis("off")

    plt.subplot(2, num_images_to_display, num_images_to_display + i + 1)
    plt.imshow(right_batch[i])
    plt.title("Right Image")
    plt.axis("off")

plt.show()
